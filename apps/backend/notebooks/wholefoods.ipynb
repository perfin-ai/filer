# %% [markdown]
# ## Investigating why whole foods receipt doesn't give good suggestions

# %%
from pathlib import Path
from filer_backend.indexing.extract import extract_text

# %% [markdown]
# ### Costco Receipt - GOOD

# %%
costco = Path('/Users/ericmelz/Desktop/Unfiled Files/2025_05_25 17_20.pdf')
text, parser = extract_text(costco)
print(f'----BEGIN----\n{text}\n-----END-----')
# Out:
# ----BEGIN----
# MfH € >LCSJkLE
# V a n N u y s t t ^ S
# 6100 Sepulveda Blvd
# Van Nuys, CA 9M11
# ( 8 1 8 ) 9 8 9 - 5 1 3 2
# 20 Member 112026428962
# 1036732 ORG CELERY
# 1700118 BUTTER CUP
# 3198 ORGANIC CAUL
# 5576 ORG EGGPLANT
# 1727736 HNYNUTKETO
# 141084 FRENCH’S ORG
# 1611893 INKED KETO
# 14670 BEEF BRISKET
# 1946966 ANTIPASTI
# 50853 HEART PALMS
# 1495950 LEMON JUICE
# 1006974 COLDBREUCOFF
# 26802 CRUMBLD FETA
# SUBTOTAL
# E 5.99
# E 13.99
# E 3.49
# E 5.99
# E 9.97
# E 6.89
# E 8.99
# E 24.42
# E 9.99
# E 10.89
# E 8.59
# E 19.99
# E 7.29
# 136.48
# TAX 0.00
# TOTAL
# XXXXXXXXXXXX9060 H
# AID: A0000000042203 VERIFIED BY PIN
# Se<f# 8872
# EFT/Deblt
# Tran ID#: 514500008872....
# App#: 078146
# Resp; APPROVED
# APPROVED *● Purchase
# AMOUNT: $136.48
# 05/25/2025 17:20 48 8316 49
# EFT/Deblt 136.48
# CHANGE 0.00
# TOTAL NUMBER OF ITEMS SOLD -
# 1 7 : 2 0 4 8 8 3 1 6 4 9
# 13
# 2100'»800803162505251720
# OP#: 49 Name: Chris C
# T h a n k Y o u !
# P 1 e a s e
# Whse:48 Trm:8 Trn:316 0P;49
# Come Again
# I t e m s S o l d ; 1 3
# 2 0 0 5 / 2 5 / 2 0 2 5 1 7 : 2 0
# -----END-----

# %%
wholefoods = Path('/Users/ericmelz/Desktop/Unfiled Files/2025_01_17_01.pdf')
text, parser = extract_text(wholefoods)
print(f'----BEGIN----\n{text}\n-----END-----')
# Out:
# ----BEGIN----
#
# -----END-----
