# %% [markdown]
# ## Investigating why the Whole Foods receipt doesn't give good suggestions

# %%
from pathlib import Path
from filer_backend.indexing.extract import extract_text

# %% [markdown]
# ### Costco Receipt - GOOD

# %%
costco = Path('/Users/ericmelz/Desktop/Unfiled Files/2025_05_25 17_20.pdf')
text, parser = extract_text(costco)
print(f'----BEGIN----\n{text}\n-----END-----')
# Out:
# ----BEGIN----
# MfH € >LCSJkLE
# V a n N u y s t t ^ S
# 6100 Sepulveda Blvd
# Van Nuys, CA 9M11
# ( 8 1 8 ) 9 8 9 - 5 1 3 2
# 20 Member 112026428962
# 1036732 ORG CELERY
# 1700118 BUTTER CUP
# 3198 ORGANIC CAUL
# 5576 ORG EGGPLANT
# 1727736 HNYNUTKETO
# 141084 FRENCH’S ORG
# 1611893 INKED KETO
# 14670 BEEF BRISKET
# 1946966 ANTIPASTI
# 50853 HEART PALMS
# 1495950 LEMON JUICE
# 1006974 COLDBREUCOFF
# 26802 CRUMBLD FETA
# SUBTOTAL
# E 5.99
# E 13.99
# E 3.49
# E 5.99
# E 9.97
# E 6.89
# E 8.99
# E 24.42
# E 9.99
# E 10.89
# E 8.59
# E 19.99
# E 7.29
# 136.48
# TAX 0.00
# TOTAL
# XXXXXXXXXXXX9060 H
# AID: A0000000042203 VERIFIED BY PIN
# Se<f# 8872
# EFT/Deblt
# Tran ID#: 514500008872....
# App#: 078146
# Resp; APPROVED
# APPROVED *● Purchase
# AMOUNT: $136.48
# 05/25/2025 17:20 48 8316 49
# EFT/Deblt 136.48
# CHANGE 0.00
# TOTAL NUMBER OF ITEMS SOLD -
# 1 7 : 2 0 4 8 8 3 1 6 4 9
# 13
# 2100'»800803162505251720
# OP#: 49 Name: Chris C
# T h a n k Y o u !
# P 1 e a s e
# ...

# %% [markdown]
# ### Whole Foods Receipt - BAD

# %%
wholefoods = Path('/Users/ericmelz/Desktop/Unfiled Files/2025_01_17_01.pdf')
text, parser = extract_text(wholefoods)
print(f'----BEGIN----\n{text}\n-----END-----')
# Out:
# ----BEGIN----
# WHOLE FOODS
#
# MARKET
#
# Beverly Hills BVH 310-274-3360
# 239 N Crescent Dr
# Beverly Hills, CA 90210 4821
#
# THNK CHOC PB PRTN BAR $5.38 F
# Qty 2 $2.69 ea
# THNK CHOC MOUSSE PIE BAR $5.38 F
# Qty 2 $2.69 ea
# BRVCUE PLT BSD CARNITAS $8.99 F
# S65WFM OG RICED CAULFLWR $5.58 F
# Qty 2 $2.79 ea
# WFM SML. REUSABLE BAG $1.19 T
# Subtotal : $26.52
# Net Sales: $26.52
# Tax: 9.50% $0.11
# Total: $26 .63
# Sold Items: 8
# Paid:
#
# American Exp *5127 $26.63
# Chip Card: AMEX CREDIT
# Chip Card AID:A00000002501
#
# RETURNS: All returns require proof
# of purchase. No returns on items
# purchased after 30 days.
# For additional information
# please visit wfm.com/returns.
# KKK KKK KKK KKK KKK KKK AK KKK KKK KKK
#
# Earn 5% back at Whole Foods Market
# with Prime Visa
#
# and an eligible Prime membership
#
# Learn more at amazon.com/wfmnvisa
#
# KKK KK KK KKK KK KKK KKK KKK KK KK KKK
# HOW WAS YOUR SHOPPING EXPERIENCE?
# Go to: http://www .wfm.com/feedback
# ...
